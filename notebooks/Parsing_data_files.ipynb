# %% [markdown]
# # Parsing System Files Code
# This notebook is intended to show how the parsing of matpower, pss/e and plexos data can be done to integrate it with the PowerSystems platform.

# %% [markdown]
# Run Pkg.build("PowerSystems") on the feature-parsing branch to be able to run this notebook

# %%
using PowerSystems
using TimeSeries

# %% [markdown]
# - Read Data files (matpower/psse/cdm)

# %%
data = PowerSystems.ParseStandardFiles(Pkg.dir("PowerSystems/data/matpower/RTS_GMLC.m"))
# Out:
# [info | PowerModels]: extending matpower format with data: branch_name 119x1
# [info | PowerModels]: extending matpower format with data: gen_name 158x3
# [info | PowerModels]: extending matpower format with data: areas 3x2
# [warn | PowerModels]: added zero cost function data for dclines
# [warn | PowerModels]: added zero cost function data for dclines
# [info | PowerModels]: extending matpower format by appending matrix "branch_name" in to "branch"
# [info | PowerModels]: extending matpower format by appending matrix "gen_name" in to "gen"
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 32 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 32 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 32 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 32 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 29 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 29 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 29 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 29 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 1 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 1 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 1 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 1 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 54 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 54 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 54 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 54 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 78 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 78 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 78 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 78 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 81 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 81 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 81 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 81 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 101 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 101 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 101 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 101 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 2 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 2 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 2 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 2 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 105 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 105 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 105 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 105 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 109 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 109 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 109 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 109 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 74 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 74 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 74 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 74 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 41 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 41 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 41 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 41 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 65 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 65 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 65 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 65 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 51 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 51 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 51 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 51 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 53 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 53 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 53 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 53 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 106 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 106 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 106 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 106 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 119 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 119 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 119 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 119 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 27 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 27 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 27 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 27 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 75 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 75 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 75 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 75 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 42 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 42 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 42 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 42 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 33 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 33 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 33 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 33 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 28 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 28 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 28 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 28 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 50 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 50 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 50 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 50 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 52 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 52 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 52 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 52 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 111 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 111 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 111 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 111 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 63 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 63 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 63 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 63 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 115 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 115 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 115 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 115 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 92 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 92 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 92 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 92 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 88 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 88 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 88 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 88 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 93 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 93 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 93 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 93 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 26 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 26 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 26 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 26 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 10 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 10 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 10 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 10 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 77 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 77 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 77 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 77 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 24 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 24 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 24 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 24 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 87 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 87 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 87 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 87 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 117 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 117 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 117 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 117 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 58 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 58 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 58 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 58 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 25 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 25 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 25 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 25 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 114 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 114 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 114 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 114 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 23 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 23 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 23 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 23 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 49 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 49 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 49 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 49 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 59 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 59 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 59 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 59 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 5 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 5 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 5 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 5 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 31 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 31 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 31 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 31 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 89 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 89 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 89 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 89 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 62 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 62 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 62 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 62 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 43 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 43 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 43 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 43 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 90 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 90 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 90 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 90 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 39 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 39 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 39 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 39 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 112 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 112 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 112 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 112 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 34 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 34 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 34 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 34 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 44 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 44 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 44 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 44 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 94 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 94 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 94 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 94 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 55 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 55 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 55 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 55 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 86 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 86 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 86 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 86 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 17 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 17 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 17 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 17 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 99 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 99 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 99 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 99 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 71 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 71 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 71 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 71 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 37 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 37 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 37 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 37 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 47 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 47 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 47 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 47 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 9 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 9 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 9 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 9 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 73 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 73 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 73 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 73 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 82 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 82 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 82 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 82 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 12 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 12 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 12 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 12 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 79 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 79 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 79 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 79 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 20 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 20 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 20 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 20 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 6 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 6 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 6 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 6 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 84 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 84 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 84 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 84 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 80 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 80 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 80 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 80 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 104 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 104 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 104 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 104 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 98 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 98 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 98 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 98 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 113 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 113 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 113 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 113 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 110 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 110 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 110 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 110 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 70 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 70 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 70 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 70 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 14 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 14 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 14 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 14 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 7 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 7 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 7 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmax values in -90 deg. to 90 deg., tightening the value on branch 7 from 180.0 to 60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 96 from -180.0 to -60.0001403060998 deg.
# [warn | PowerModels]: this code only supports angmin values in -90 deg. to 90 deg., tightening the value on branch 96 from -180.0 to -60.0001403060998 deg.
# ...
# [warn | PowerModels]: the voltage setpoint on generator 126 does not match the value at bus 313
# [warn | PowerModels]: the voltage setpoint on generator
does not match the value at bus 118
# [warn | PowerModels]: the voltage setpoint on generator 36 does not match the value at bus 215
# [warn | PowerModels]: the voltage setpoint on generator 36 does not match the value at bus 215
# [warn | PowerModels]: the voltage setpoint on generator 66 does not match the value at bus 316
# [warn | PowerModels]: the voltage setpoint on generator 66 does not match the value at bus 316
# [warn | PowerModels]: the voltage setpoint on generator 138 does not match the value at bus 320
# [warn | PowerModels]: the voltage setpoint on generator 138 does not match the value at bus 320
# [warn | PowerModels]: the voltage setpoint on generator 85 does not match the value at bus 215
# [warn | PowerModels]: the voltage setpoint on generator 85 does not match the value at bus 215
# [warn | PowerModels]: the voltage setpoint on generator 147 does not match the value at bus 118
# [warn | PowerModels]: the voltage setpoint on generator 147 does not match the value at bus 118
# [warn | PowerModels]: the voltage setpoint on generator 135 does not match the value at bus 313
# [warn | PowerModels]: the voltage setpoint on generator 135 does not match the value at bus 313
# [warn | PowerModels]: the voltage setpoint on generator 48 does not match the value at bus 301
# [warn | PowerModels]: the voltage setpoint on generator 48 does not match the value at bus 301
# [warn | PowerModels]: the voltage setpoint on generator 103 does not match the value at bus 313
# [warn | PowerModels]: the voltage setpoint on generator 103 does not match the value at bus 313
# [warn | PowerModels]: the voltage setpoint on generator 30 does not match the value at bus 202
# [warn | PowerModels]: the voltage setpoint on generator 30 does not match the value at bus 202
# [warn | PowerModels]: the voltage setpoint on generator 3 does not match the value at bus 101
# [warn | PowerModels]: the voltage setpoint on generator 3 does not match the value at bus 101
# [warn | PowerModels]: the from bus voltage setpoint on dc line 1 does not match the value at bus 113
# [warn | PowerModels]: the from bus voltage setpoint on dc line 1 does not match the value at bus 113
# [warn | PowerModels]: the to bus voltage setpoint on dc line 1 does not match the value at bus 316
# [warn | PowerModels]: the to bus voltage setpoint on dc line 1 does not match the value at bus 316
# [warn | PowerModels]: pwl x value 0.0033333 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.0033333 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.0066667 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.0066667 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.01 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.01 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.0033333 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.0033333 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.0066667 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.0066667 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.01 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.01 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.0033333 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.0033333 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.0066667 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.0066667 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.01 is outside the generator bounds 0.0-0.0
# [warn | PowerModels]: pwl x value 0.01 is outside the generator bounds 0.0-0.0
# Dict{String,Any} with 13 entries:
#   "bus"            => Dict{String,Any}(Pair{String,Any}("109", Dict{String,Any}…
#   "source_type"    => "matpower"
#   "name"           => "RTS_GMLC"
#   "dcline"         => Dict{String,Any}(Pair{String,Any}("1", Dict{String,Any}(P…
#   "source_version" => v"2.0.0"
#   "gen"            => Dict{String,Any}(Pair{String,Any}("32", Dict{String,Any}(…
#   "branch"         => Dict{String,Any}(Pair{String,Any}("32", Dict{String,Any}(…
#   "version"        => v"0.7.2+"
#   "baseMVA"        => 100.0
#   "per_unit"       => true
#   "areas"          => Dict{String,Any}(Pair{String,Any}("1", Dict{String,Any}(P…
#   "shunt"          => Dict{String,Any}(Pair{String,Any}("1", Dict{String,Any}(P…
#   "load"           => Dict{String,Any}(Pair{String,Any}("32", Dict{String,Any}(…

# %% [markdown]
# - Parse PowerModels dict to PowerSystems dict

# %%
ps_dict = PowerSystems.pm2ps_dict(data);

# %% [markdown]
# - Parse TimeSeries data files (CSV) to dict

# %%
time_series = PowerSystems.read_data_files(Pkg.dir("PowerSystems/data/forecasts/RTS_GMLC_forecasts"));
# Out:
# Parsing csv timeseries files in CSP ...
# Successfully parsed CSP
# Parsing csv timeseries files in HYDRO ...
# Successfully parsed HYDRO
# Parsing csv timeseries files in Load ...
# Successfully parsed Load
# Parsing csv timeseries files in PV ...
# Successfully parsed PV
# Parsing csv timeseries files in RTPV ...
# Successfully parsed RTPV
# Parsing csv timeseries files in WIND ...
# Successfully parsed WIND

# %% [markdown]
# - Add RealTime Simulation data to PowerSystems Dict

# %%
ps_dict = PowerSystems.add_realtime_ts(ps_dict,time_series);

# %% [markdown]
# - PowerSystems Dict to PowerSystems Struct

# %%
Buses, Generators, Storage, Branches, Loads, LoadZones  = PowerSystems.ps_dict2ps_struct(ps_dict);

# %% [markdown]
# - Parse TimeSeries to Forecast Dict

# %%
forecast_gen = PowerSystems.make_forecast_dict(time_series,Day(1),24,Generators)
forecast_load = PowerSystems.make_forecast_dict(time_series,Day(1),24,Loads, LoadZones);
# Out:
# No forecast found for 322_CT_6
# No forecast found for 321_CC_1
# No forecast found for 202_STEAM_3
# No forecast found for 315_STEAM_1
# No forecast found for 223_CT_4
# No forecast found for 213_CT_1
# No forecast found for 313_CC_1
# No forecast found for 123_STEAM_2
# No forecast found for 223_CT_6
# No forecast found for 202_CT_2
# No forecast found for 101_STEAM_3
# No forecast found for 302_CT_1
# No forecast found for 123_CT_1
# No forecast found for 113_CT_3
# No forecast found for 302_CT_3
# No forecast found for 215_CT_4
# No forecast found for 102_STEAM_3
# No forecast found for 301_CT_4
# No forecast found for 202_CT_1
# No forecast found for 113_CT_2
# No forecast found for 221_CC_1
# No forecast found for 315_CT_7
# No forecast found for 223_CT_5
# No forecast found for 215_CT_5
# No forecast found for 114_SYNC_COND_1
# No forecast found for 323_CC_1
# No forecast found for 101_STEAM_4
# No forecast found for 113_CT_1
# No forecast found for 223_STEAM_3
# No forecast found for 318_CC_1
# No forecast found for 307_CT_2
# No forecast found for 213_CT_2
# No forecast found for 113_CT_4
# No forecast found for 315_STEAM_3
# No forecast found for 118_CC_1
# No forecast found for 315_CT_8
# No forecast found for 302_CT_2
# No forecast found for 218_CC_1
# No forecast found for 213_CC_3
# No forecast found for 115_STEAM_3
# No forecast found for 323_CC_2
# No forecast found for 101_CT_1
# No forecast found for 314_SYNC_COND_1
# No forecast found for 115_STEAM_2
# No forecast found for 101_CT_2
# No forecast found for 322_CT_5
# No forecast found for 214_SYNC_COND_1
# No forecast found for 315_STEAM_5
# No forecast found for 207_CT_2
# No forecast found for 123_STEAM_3
# No forecast found for 223_STEAM_1
# No forecast found for 123_CT_5
# No forecast found for 301_CT_1
# No forecast found for 223_STEAM_2
# No forecast found for 202_STEAM_4
# No forecast found for 313_STORAGE_1
# No forecast found for 116_STEAM_1
# No forecast found for 315_STEAM_4
# No forecast found for 315_STEAM_2
# No forecast found for 115_STEAM_1
# No forecast found for 121_NUCLEAR_1
# No forecast found for 102_CT_2
# No forecast found for 123_CT_4
# No forecast found for 207_CT_1
# No forecast found for 301_CT_3
# No forecast found for 316_STEAM_1
# No forecast found for 102_CT_1
# No forecast found for 216_STEAM_1
# No forecast found for 315_CT_6
# No forecast found for 201_STEAM_3
# No forecast found for 201_CT_2
# No forecast found for 201_CT_1
# No forecast found for 301_CT_2
# No forecast found for 302_CT_4
# No forecast found for 307_CT_1
# No forecast found for 102_STEAM_4
# No forecast found for 107_CC_1

# %% [markdown]
# - Parse Forecast Dict to Forecast Struct

# %%
f_gen = PowerSystems.make_forecast_array(forecast_gen)
f_load = PowerSystems.make_forecast_array(forecast_load);
